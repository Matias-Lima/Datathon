# %%
from arch.bootstrap import StationaryBootstrap
import pandas as pd
import numpy as np
from scipy import stats
import statsmodels.api as sm

# %%
sp_tech = pd.read_excel("C:/Users/limam/Documents/GitHub/Datathon_2023/Dados/sinais_ind_tecnicos.xlsx")

# %%
sp_tech

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from scipy import stats
from sklearn.utils import resample

# Read the Excel file into a pandas DataFrame
sp_tech = pd.read_excel("C:/Users/limam/Documents/GitHub/Datathon_2023/Dados/sinais_ind_tecnicos.xlsx")

# Assuming 'premium' is already a column in sp_tech DataFrame
t = len(sp_tech)
n = 14  # number of technical indicators
resultados = np.zeros((n, 4))  # To store coefficient, t-stat, p-value, and R^2
residuos = np.zeros((t - 1, n))  # t-1 because we're starting from the second element
j = 3  # Column index where technical indicators data starts

sp_tech['return'] = sp_tech['Adj Close'].pct_change()


# Loop for regression
for i in range(n):
    Y = sp_tech['return'][2:t].values
    X = sp_tech.iloc[1:(t-1), j].values.reshape(-1, 1)
    X = sm.add_constant(X)  # Add the intercept
    model = sm.OLS(Y, X).fit()    
    # Bootstrapping
    coef_bootstraps = []
    
    for _ in range(1000):
        # Resample with replacement
        index_resampled = resample(np.arange(len(X)), replace=True)
        X_resampled = X[index_resampled]
        Y_resampled = Y[index_resampled]
        model_resampled = sm.OLS(Y_resampled, X_resampled).fit()
        coef_bootstraps.append(model_resampled.params[1])  # Get the coefficient for the indicator

    coef_bootstraps = np.array(coef_bootstraps)
    std_error = coef_bootstraps.std(ddof=1)
    
    # Calculate t-statistic and p-value
    coef = model.params[1]
    t_stat = coef / std_error
    p_value = 2 * (1 - stats.t.cdf(np.abs(t_stat), df=n-2))  # Two-tailed test
    
    # Get R-squared from the model
    r_squared = model.rsquared
    
    # Store results in resultados array
    resultados[i, :] = coef, t_stat, p_value, r_squared
    
    # Store residuals in residuos array
    #residuos = model.resid

    # Move to the next indicator
    j += 1

# Create a DataFrame to display the results nicely
results_df = pd.DataFrame(resultados, columns=['Coefficient', 'T-Statistic', 'P-Value', 'R-Squared'])

print(results_df)
# Out:
#     Coefficient  T-Statistic   P-Value  R-Squared
# 0      0.018293     1.899787  0.081754   0.008158
# 1      0.019564     2.093118  0.058252   0.009331
# 2      0.016353     1.712133  0.112569   0.006511
# 3      0.020147     2.186348  0.049330   0.009854
# 4      0.018410     1.942438  0.075921   0.008262
# 5      0.018368     1.972859  0.071997   0.008191
# 6      0.018035     1.928909  0.077729   0.007738
# 7      0.018767     2.048024  0.063091   0.008442
# 8      0.015792     1.669615  0.120853   0.006036
# 9      0.013484     1.438528  0.175851   0.004350
# 10     0.012171     1.305235  0.216285   0.003591
# 11     0.009888     1.024731  0.325704   0.002326
# 12     0.009916     1.065232  0.307736   0.002397
# 13     0.011090     1.215779  0.247446   0.002953

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

# Read the Excel file into a pandas DataFrame
sp_tech = pd.read_excel("C:/Users/limam/Documents/GitHub/Datathon_2023/Dados/sinais_ind_tecnicos.xlsx")

# Handle NaN values for 'Adj Close', perhaps with forward fill or dropna:
sp_tech['Adj Close'].fillna(method='ffill', inplace=True)

# Calculate the percentage returns of the 'Adj Close' column
sp_tech['return'] = sp_tech['Adj Close'].pct_change().dropna()

# Initialization
n = 14  # Number of technical indicators
t = len(sp_tech)
resultados = np.zeros((n, 4))  # To store coefficient, t-statistic, R^2, and p-value
residuos = np.zeros((t - 2, n))  # t-2 because the first return will be NaN
summaries = []  # To store summary objects for later use
j = 3  # Column index where technical indicators data starts

# Loop for regression
for i in range(n):
    # The dependent variable (Y) and independent variable (X)
    Y = sp_tech['return'][1:].values  # Use values after the first NaN
    X = sp_tech.iloc[:-1, j+i].values.reshape(-1, 1)  # Use values up to the last to match with Y
    X = sm.add_constant(X)  # Add the intercept
    
    # Perform regression
    model = sm.OLS(Y, X).fit()
    summaries.append(model.summary())
    
    # Store results
    resultados[i] = [model.params[1], model.tvalues[1], model.rsquared, model.pvalues[1]]
    #residuos = model.resid
    
    # Print out each summary if needed
    print(summaries[i])

# Now, 'resultados' contains the regression results for each technical indicator
# and 'residuos' contains the residuals for each regression.
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     3.739
# Date:                Sun, 05 Nov 2023   Prob (F-statistic):             0.0538
# Time:                        18:30:40   Log-Likelihood:                 400.79
# No. Observations:                 452   AIC:                            -797.6
# Df Residuals:                     450   BIC:                            -789.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0051      0.007      0.716      0.475      -0.009       0.019
# x1             0.0184      0.010      1.934      0.054      -0.000       0.037
# ==============================================================================
# Omnibus:                       18.227   Durbin-Watson:                   1.905
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               41.601
# Skew:                           0.126   Prob(JB):                     9.26e-10
# Kurtosis:                       4.465   Cond. No.                         2.83
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     4.278
# Date:                Sun, 05 Nov 2023   Prob (F-statistic):             0.0392
# Time:                        18:30:41   Log-Likelihood:                 401.05
# No. Observations:                 452   AIC:                            -798.1
# Df Residuals:                     450   BIC:                            -789.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0044      0.007      0.615      0.539      -0.010       0.019
# x1             0.0196      0.009      2.068      0.039       0.001       0.038
# ==============================================================================
# Omnibus:                       17.665   Durbin-Watson:                   1.903
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               39.955
# Skew:                           0.116   Prob(JB):                     2.11e-09
# Kurtosis:                       4.438   Cond. No.                         2.83
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     2.983
# Date:                Sun, 05 Nov 2023   Prob (F-statistic):             0.0848
# Time:                        18:30:41   Log-Likelihood:                 400.41
# No. Observations:                 452   AIC:                            -796.8
# Df Residuals:                     450   BIC:                            -788.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0062      0.007      0.862      0.389      -0.008       0.020
# x1             0.0164      0.010      1.727      0.085      -0.002       0.035
# ==============================================================================
# Omnibus:                       17.971   Durbin-Watson:                   1.870
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.866
# Skew:                           0.121   Prob(JB):                     1.34e-09
# Kurtosis:                       4.453   Cond. No.                         2.83
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     4.519
# Date:                Sun, 05 Nov 2023   Prob (F-statistic):             0.0341
# Time:                        18:30:41   Log-Likelihood:                 401.17
# No. Observations:                 452   AIC:                            -798.3
# Df Residuals:                     450   BIC:                            -790.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0040      0.007      0.546      0.585      -0.010       0.018
# x1             0.0202      0.010      2.126      0.034       0.002       0.039
# ==============================================================================
# Omnibus:                       15.823   Durbin-Watson:                   1.879
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               34.060
# Skew:                           0.096   Prob(JB):                     4.02e-08
# Kurtosis:                       4.331   Cond. No.                         2.85
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     3.787
# Date:                Sun, 05 Nov 2023   Prob (F-statistic):             0.0523
# Time:                        18:30:41   Log-Likelihood:                 400.81
# No. Observations:                 452   AIC:                            -797.6
# Df Residuals:                     450   BIC:                            -789.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0051      0.007      0.707      0.480      -0.009       0.019
# x1             0.0185      0.010      1.946      0.052      -0.000       0.037
# ==============================================================================
# Omnibus:                       17.874   Durbin-Watson:                   1.858
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.367
# Skew:                           0.123   Prob(JB):                     1.72e-09
# Kurtosis:                       4.443   Cond. No.                         2.83
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     3.644
# Date:                Sun, 05 Nov 2023   Prob (F-statistic):             0.0569
# Time:                        18:30:41   Log-Likelihood:                 400.74
# No. Observations:                 452   AIC:                            -797.5
# Df Residuals:                     450   BIC:                            -789.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0052      0.007      0.717      0.474      -0.009       0.019
# x1             0.0182      0.010      1.909      0.057      -0.001       0.037
# ==============================================================================
# Omnibus:                       16.416   Durbin-Watson:                   1.868
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.691
# Skew:                           0.082   Prob(JB):                     1.08e-08
# Kurtosis:                       4.386   Cond. No.                         2.84
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     3.544
# Date:                Sun, 05 Nov 2023   Prob (F-statistic):             0.0604
# Time:                        18:30:41   Log-Likelihood:                 400.69
# No. Observations:                 452   AIC:                            -797.4
# Df Residuals:                     450   BIC:                            -789.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0047      0.007      0.627      0.531      -0.010       0.019
# x1             0.0181      0.010      1.883      0.060      -0.001       0.037
# ==============================================================================
# Omnibus:                       17.771   Durbin-Watson:                   1.872
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.689
# Skew:                           0.109   Prob(JB):                     1.46e-09
# Kurtosis:                       4.454   Cond. No.                         2.95
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     3.755
# Date:                Sun, 05 Nov 2023   Prob (F-statistic):             0.0533
# Time:                        18:30:41   Log-Likelihood:                 400.79
# No. Observations:                 452   AIC:                            -797.6
# Df Residuals:                     450   BIC:                            -789.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0046      0.007      0.627      0.531      -0.010       0.019
# x1             0.0186      0.010      1.938      0.053      -0.000       0.037
# ==============================================================================
# Omnibus:                       17.266   Durbin-Watson:                   1.869
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               39.898
# Skew:                           0.082   Prob(JB):                     2.17e-09
# Kurtosis:                       4.446   Cond. No.                         2.91
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     2.765
# Date:                Sun, 05 Nov 2023   Prob (F-statistic):             0.0970
# Time:                        18:30:41   Log-Likelihood:                 400.30
# No. Observations:                 452   AIC:                            -796.6
# Df Residuals:                     450   BIC:                            -788.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0064      0.007      0.878      0.381      -0.008       0.021
# x1             0.0159      0.010      1.663      0.097      -0.003       0.035
# ==============================================================================
# Omnibus:                       18.589   Durbin-Watson:                   1.884
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               43.114
# Skew:                           0.124   Prob(JB):                     4.34e-10
# Kurtosis:                       4.492   Cond. No.                         2.86
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     1.994
# Date:                Sun, 05 Nov 2023   Prob (F-statistic):              0.159
# Time:                        18:30:41   Log-Likelihood:                 399.91
# No. Observations:                 452   AIC:                            -795.8
# Df Residuals:                     450   BIC:                            -787.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0075      0.007      1.013      0.311      -0.007       0.022
# x1             0.0136      0.010      1.412      0.159      -0.005       0.032
# ==============================================================================
# Omnibus:                       17.363   Durbin-Watson:                   1.868
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               38.735
# Skew:                           0.117   Prob(JB):                     3.88e-09
# Kurtosis:                       4.415   Cond. No.                         2.92
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.648
# Date:                Sun, 05 Nov 2023   Prob (F-statistic):              0.200
# Time:                        18:30:41   Log-Likelihood:                 399.74
# No. Observations:                 452   AIC:                            -795.5
# Df Residuals:                     450   BIC:                            -787.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0085      0.007      1.173      0.242      -0.006       0.023
# x1             0.0123      0.010      1.284      0.200      -0.007       0.031
# ==============================================================================
# Omnibus:                       17.205   Durbin-Watson:                   1.855
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               38.038
# Skew:                           0.119   Prob(JB):                     5.50e-09
# Kurtosis:                       4.401   Cond. No.                         2.86
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.069
# Date:                Sun, 05 Nov 2023   Prob (F-statistic):              0.302
# Time:                        18:30:41   Log-Likelihood:                 399.45
# No. Observations:                 452   AIC:                            -794.9
# Df Residuals:                     450   BIC:                            -786.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0096      0.008      1.282      0.201      -0.005       0.024
# x1             0.0100      0.010      1.034      0.302      -0.009       0.029
# ==============================================================================
# Omnibus:                       17.601   Durbin-Watson:                   1.849
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               39.579
# Skew:                           0.118   Prob(JB):                     2.54e-09
# Kurtosis:                       4.430   Cond. No.                         2.95
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.103
# Date:                Sun, 05 Nov 2023   Prob (F-statistic):              0.294
# Time:                        18:30:41   Log-Likelihood:                 399.47
# No. Observations:                 452   AIC:                            -794.9
# Df Residuals:                     450   BIC:                            -786.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0099      0.007      1.378      0.169      -0.004       0.024
# x1             0.0100      0.010      1.050      0.294      -0.009       0.029
# ==============================================================================
# Omnibus:                       17.426   Durbin-Watson:                   1.848
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               39.142
# Skew:                           0.114   Prob(JB):                     3.17e-09
# Kurtosis:                       4.424   Cond. No.                         2.83
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.356
# Date:                Sun, 05 Nov 2023   Prob (F-statistic):              0.245
# Time:                        18:30:41   Log-Likelihood:                 399.60
# No. Observations:                 452   AIC:                            -795.2
# Df Residuals:                     450   BIC:                            -787.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0090      0.007      1.218      0.224      -0.006       0.024
# x1             0.0112      0.010      1.164      0.245      -0.008       0.030
# ==============================================================================
# Omnibus:                       17.290   Durbin-Watson:                   1.845
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               38.355
# Skew:                           0.119   Prob(JB):                     4.69e-09
# Kurtosis:                       4.407   Cond. No.                         2.91
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
